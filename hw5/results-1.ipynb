# %% [markdown]
# #### Table1. Performance of Naive Bayes,  SVM, SVM with Gaussian Kernel, MLP on Fashion-MNIST
#
# \begin{array}{llcr}
# \hline
# trainer & \text{Performance} & \text{Accu_train} &  \text{Accu_valid}\\ \hline
# XY & \text{Naive Bayes(Gaussian)} & 58.49 & 58.09 \\
# XY & \text{ SVM(C=1e-3,gamma = 1e-6, kernel = "poly")} & 85.85 & 83.98\\
# YQ & \text{ SVM(C=1e-2,gamma = 1e-6, kernel = "poly")} & 93.9 & 87.51\\
# YQ & \text{ SVM(C=1e-1,gamma = 1e-6, kernel = "poly")} & 98.95 & 88.26\\
# AI & \text{ SVM(C=1e0,gamma = 1e-6, kernel = "poly")} & 99.91 & 87.88\\
# AI & \text{ SVM(C=1e1,gamma = 1e-6, kernel = "poly")} & 100& 87.47\\
# LF & \text{ SVM(C=1e2,gamma = 1e-6, kernel = "poly")} & 100 & 87.08\\
# LF & \text{ SVM(C=1e3,gamma = 1e-6, kernel = "poly")} & 100 & 87.08\\
# \hline\\
# LJ & \text{ SVM(C=1e-3, gamma = 1e-6, kernel = "rbf")} & 10.20 & 9.79\\
# LJ & \text{ SVM(C=1e-2, gamma = 1e-6, kernel = "rbf")} & 64.85 & 64.32\\
# XY & \text{ SVM(C=1e-1, gamma = 1e-6, kernel = "rbf")} & 84.41 & 81.93\\
# XY & \text{ SVM(C=1e-0, gamma = 1e-6, kernel = "rbf")} & 97.81 & 89.53\\
# YQ & \text{ SVM(C=1e1, gamma = 1e-6, kernel = "rbf")} & 100 & 89.31\\
# YQ & \text{ SVM(C=1e2, gamma = 1e-6, kernel = "rbf")} & 100 & 89.31\\
# AI & \text{ SVM(C=1e3, gamma = 1e-6, kernel = "rbf")} & 100 & 89.57\\
# \hline\\
# YQ & \text{MLP (1 hidden layses with neurons:[16])} & 62.25 & 62.03 \\
# YQ & \text{MLP (1 hidden layses with neurons:[32])} & 74.23 & 73.09 \\
# AI & \text{MLP (1 hidden layses with neurons:[64])} & 83.24 & 81.71 \\
# AI & \text{MLP (1 hidden layses with neurons:[128])} & 86.71 & 84.11\\
# LF & \text{MLP (1 hidden layses with neurons:[256])} & 88.85 & 85.47 \\
# LF & \text{MLP (1 hidden layses with neurons:[512])} & 88.75 & 85.18 \\
# LJ & \text{MLP (1 hidden layses with neurons:[1024])} & 91.06 & 86.68 \\
# LJ & \text{MLP (2 hidden layses with neurons:[1024, 1024])} & 88.85 & 85.02 \\
# XY & \text{MLP (2 hidden layses with neurons:[1024, 512])} & 90.69 & 86.32 \\
# XY & \text{MLP (2 hidden layses with neurons:[1024, 256])} & 89.02 & 86.27 \\
# YQ & \text{MLP (2 hidden layses with neurons:[1024, 128])} & 90.20 & 86.62 \\
# YQ & \text{MLP (2 hidden layses with neurons:[1024, 64])} & 70.01 & 69.24 \\
# AI & \text{MLP (2 hidden layses with neurons:[1024, 32])} & 60.09 & 59.23 \\
# AI & \text{MLP (2 hidden layses with neurons:[1024, 16])} & 9.95 & 10.12 \\
# LF & \text{MLP (2 hidden layses with neurons:[512, 512])} & 89.44 & 85.06 \\
# LF & \text{MLP (2 hidden layses with neurons:[512, 256])} & 91.15 & 86.74 \\
# LJ & \text{MLP (2 hidden layses with neurons:[512, 128])} & 89.11 & 85.03 \\
# LJ & \text{MLP (2 hidden layses with neurons:[512, 64])} & 76.73 & 75.85 \\
# XY & \text{MLP (2 hidden layses with neurons:[512, 32])} & 26.61 & 25.83 \\
# XY & \text{MLP (2 hidden layses with neurons:[512, 16])} & 9.92 & 10.19 \\
# YQ & \text{MLP (2 hidden layses with neurons:[256, 256])} & 84.94 & 82.57 \\
# YQ & \text{MLP (2 hidden layses with neurons:[256, 128])} & 89.47 & 85.43 \\
# AI & \text{MLP (2 hidden layses with neurons:[256, 64])} & 88.53 & 85.88 \\
# AI & \text{MLP (2 hidden layses with neurons:[256, 32])} & 47.36 & 45.97 \\
# LF & \text{MLP (2 hidden layses with neurons:[256, 16])} & 37.34 & 36.28 \\
# LF & \text{MLP (2 hidden layses with neurons:[128, 128])} &88.05 & 84.73 \\
# LJ & \text{MLP (2 hidden layses with neurons:[128, 64])} & 87.07 & 84.75 \\
# LJ & \text{MLP (2 hidden layses with neurons:[128, 32])} & 82.83 & 81.70 \\
# XY & \text{MLP (2 hidden layses with neurons:[128, 16])} & 47.63 & 47.02 \\
# XY & \text{MLP (2 hidden layses with neurons:[64, 64])} & 85.49 & 83.62 \\
# YQ & \text{MLP (2 hidden layses with neurons:[64, 32])} & 88.13 & 85.88 \\
# YQ & \text{MLP (2 hidden layses with neurons:[64, 16])} & 72.78 & 71.74 \\
# AI & \text{MLP (2 hidden layses with neurons:[32, 32])} & 75.87 &75.16 \\
# AI & \text{MLP (2 hidden layses with neurons:[32, 16])} & 86.82& 84.97\\
# AI & \text{MLP (2 hidden layses with neurons:[16, 16])} & 57.81 & 56.74\\
# \hline
# \end{array}

# %% [markdown]
# Table2. Performance of Naive Bayes,  SVM, SVM with Gaussian Kernel, MLP on Adult Income Dataset
#
# \begin{array}{clcccccccc}
# \hline
# \text{trainer} & \text{Performance} & Accuracy & Accuracy & Precision & Precision & Recall & Recall & F Score & F Score \\
# \ & {      } & \text{Training Set} & \text{Validating Set} & \text{Training Set} & \text{Validating Set} & \text{Training Set} & \text{Validating Set} & \text{Training Set} & \text{Validating Set}\\
# \hline
# XY & \text{Naive Bayes(Gaussian)} & 79.8 & 78.96 & 78 & 77 & 80 & 79 & 77 & 76 \\
# \hline\\
# LF & \text{ SVM(C=1e-3, gamma=1e-6, kernel = 'poly')} & 76.15 & 75.39 & 58 & 57 & 76 & 75 & 66 & 65 \\
# LJ & \text{ SVM(C=1e-2, gamma=1e-6, kernel = 'poly')} & 76.42 & 75.71 & 58 & 57 & 76 & 76& 66 & 65 \\
# XY & \text{ SVM(C=1e-1, gamma=1e-6, kernel = 'poly')} & 76.02 & 75.69 & 58 & 57 & 76 & 76& 66 & 65 \\
# YQ & \text{ SVM(C=1e-0, gamma=1e-6, kernel = 'poly')} & 76.08 & 75.36 & 61& 64 & 76 & 75& 66(1.1) & 65(0.2) \\
# AI & \text{ SVM(C=1e1, gamma=1e-6, kernel = 'poly')} & 76.15 & 75.39 & 58& 57 & 76 & 75& 66 & 65 \\
# LF & \text{ SVM(C=1e2, gamma=1e-6, kernel = 'poly')} & 76.15 & 75.39 & 58 & 57 & 76 & 75 & 66 & 65 \\
# LJ  & \text{ SVM(C=1e3, gamma=1e-6, kernel = 'poly')} & 75.87 & 76.03 & 58 & 58 & 76 & 76& 65 & 65 \\
# \hline \\
# XY & \text{ SVM(C=1e-3, gamma = 1e-6, kernel = 'rbf'}) & 76.02 & 75.69 & 58 & 57 & 76 & 76 & 66 & 65 \\
# YQ & \text{ SVM(C=1e-2, gamma = 1e-6, kernel = 'rbf'}) & 75.82 & 74.99 & 62 & 62 & 76 & 75 & 66(1) & 65(1) \\
# AI & \text{ SVM(C=1e-1, gamma = 1e-6, kernel = 'rbf'}) & 76.15 &75.39 & 58 & 57 & 76 & 75 & 66 & 65 \\
# LF & \text{ SVM(C=1e-0, gamma = 1e-6, kernel = 'rbf'}) & 76.15 & 75.39 & 58 & 57 & 76 & 75 & 66 & 65 \\
# LJ & \text{ SVM(C=1e1, gamma = 1e-6, kernel = 'rbf'}) & 75.87 & 76.03 & 58 & 58 & 76 & 76 & 65 & 66 \\
# XY & \text{ SVM(C=1e2, gamma = 1e-6, kernel = 'rbf'}) & 76.69 & 76.43 & 82 & 82 & 77 & 76 & 67 & 67 \\
# YQ & \text{ SVM(C=1e3, gamma = 1e-6, kernel = 'rbf'}) & 72.56 & 71.48 & 63 & 62 & 73 & 71 & 66(10) & 65(9) \\
# AI & \text{ SVM(C=best, gamma = 1e-6, kernel = 'rbf'}) & TBA & TBA & TBA & TBA & TBA & TBA & TBA & TBA \\
# LF & \text{MLP (1 hidden layses with neurons:[4])} & 75.04 & 74.41 & 65 & 64 & 75 & 74 & 67 & 65 \\
# LJ & \text{MLP (1 hidden layses with neurons:[8])} & 84.81 & 84.41 & 84 & 84 & 85 & 84 & 84 & 84 \\
# XY & \text{MLP (1 hidden layses with neurons:[16])} & 84.81 & 84.47 & 84  & 84 & 85 & 84 & 84 & 84 \\
# YQ & \text{MLP (1 hidden layses with neurons:[32])} & 79.40 & 79.23& 78 & 78 & 79 & 79 & 75(34) & 75(36)  \\
# AI & \text{MLP (2 hidden layses with neurons:[32, 32])} & 83.27 & 83.57 & 83 & 83 & 83 & 84 & 83 & 83 \\
# LF & \text{MLP (2 hidden layses with neurons:[32, 16])} & 83.58 & 83.85 & 83 & 83 & 84 & 84 & 83 & 83 \\
# LJ & \text{MLP (2 hidden layses with neurons:[32, 8])} & 85.33 & 84.50 & 85 & 84 & 85 & 85 & 85 & 84 \\
# XY & \text{MLP (2 hidden layses with neurons:[32, 4])} & 84.98 & 84.66& 84 & 84 & 85 & 85 & 84 & 84 \\
# YQ & \text{MLP (2 hidden layses with neurons:[16, 16])} & 79.51 & 79.45 & 78 & 79 & 80 & 79 & 75(35)  & 75(36)  \\
# AI & \text{MLP (2 hidden layses with neurons:[16, 8])} & 81.54 & 81.37& 80 & 80 &82 & 81 & 80 & 80\\
# LF & \text{MLP (2 hidden layses with neurons:[16, 4])} & 81.78 & 81.83 & 80 & 81 & 82 & 82 & 80 & 81 \\
# LJ & \text{MLP (2 hidden layses with neurons:[16, 4])} & 85.24 & 85.15 & 85 & 85 & 85 & 85 & 85 & 85 \\
# XY & \text{MLP (2 hidden layses with neurons:[8, 8])} & 84.76 & 84.33 & 84 & 84 & 85 & 84 & 84 & 84 \\
# YQ & \text{MLP (2 hidden layses with neurons:[8, 4])} & 78.83 & 78.73 & 77 & 78 & 79 & 79 & 74(30)  & 74(32)  \\
# AI & \text{MLP (2 hidden layses with neurons:[4, 4])} & 76.15 & 75.39 & 58 & 57 & 76 & 75 & 66 & 65 \\
# \hline
# LF & \text{MLP (3 hidden layses with neurons:[32, 32, 32])} & 83.88 & 83.46 & 83 & 83 & 84 & 83 & 83 & 83 \\
# LJ & \text{MLP (3 hidden layses with neurons:[16, 16, 16])} & 85.13 & 84.55 & 84 & 84 & 85 & 85 & 85 & 84 \\
# XY & \text{MLP (3 hidden layses with neurons:[8, 8, 8])} & 84.61 & 84.23 & 84 & 83 & 85 & 84 & 84 & 84 \\
# YQ & \text{MLP (3 hidden layses with neurons:[4, 4, 4])} & 76.15 & 75.83 & 70 & 75 & 76 & 76 & 66(1.6)  & 65(1.9)  \\
# AI & \text{MLP (3 hidden layses with neurons:[32, 16, 8])} & 76.14 & 75.39 & 58 & 57 & 76 & 75 & 66 & 65 \\
# \hline
# LF & \text{MLP (4 hidden layses with neurons:[32, 16, 8, 4])} & 83.19 & 82.89 & 82 & 82 & 83 & 83 & 82 & 81 \\
# \hline
# \end{array}

# %% [markdown]
# Table3 or Fig0: statistics of dataset Fashion-MNIST
#
# Table3 or Fig1: statistics of dataset Adult Income

# %% [markdown]
# Fig2. Learning Curve of  SVC of different C (Data from table 1)
# a. on Fashion-MNIST  b. on Adult Income
#
# Fig3. Learning Curve of SVC with Gaussian Kernel of different C ( select best gamma) (Data from table 1)
# a. on Fashion-MNIST  b. on Adult Income
#
# Fig4. Learning Curve of SVC with Gaussian Kernel of different gamma (select best C) (Data from table 1)
# a. on Fashion-MNIST  b. on Adult Income
#
# Fig5 Learning Curve of MLP with one hidden layer on different features in each hidden layer (each layer using same number of features, select  )
# a. on Fashion-MNIST  b. on Adult Income
#
# Fig6 Learning Curve of MLP with 2 hidden layers on different features in each hidden layer (each layer using same number of features, select  )
# a. on Fashion-MNIST  b. on Adult Income
